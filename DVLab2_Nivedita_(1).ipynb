# %% [markdown]
# <a href="https://colab.research.google.com/github/nivedita98/DV_LAbAssignments/blob/main/DVLab2_Nivedita_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_excel("rainfall.xls")
print(df)
# Out:
#       SD NO.                             SD_Name  YEAR   JAN   FEB    MAR  \
# 0          1           ANDAMAN & NICOBAR ISLANDS  1951  82.7   7.2    0.0
# 1          2                   ARUNACHAL PRADESH  1951  31.8  65.3  309.9
# 2          3                   ASSAM & MEGHALAYA  1951   4.5   2.9   54.6
# 3          4  NAGALAND, MANIPUR, MIZORAM,TRIPURA  1951   3.9   0.2   62.4
# 4          5     SUB-HIMALAYAN W BENGAL & SIKKIM  1951   1.0   0.5   22.7
# ...      ...                                 ...   ...   ...   ...    ...
# 2296      32                   COASTAL KARNATAKA  2014   0.0   0.1    2.6
# 2297      33            NORTH INTERIOR KARNATAKA  2014   0.0   6.1   29.2
# 2298      34            SOUTH INTERIOR KARNATAKA  2014   0.4   2.4   17.7
# 2299      35                              KERALA  2014   4.6  10.3   17.9
# 2300      36                        LAKSHADWEEP   2014  53.2  16.1    4.4
#
#         APR    MAY    JUN     JUL     AUG    SEP    OCT    NOV    DEC  ANNUAL  \
# ...

# %%
Text = 'From an academic point of view, this representation can be considered as a mapping between the original data  and graphic elements. The mapping determines how the attributes of these elements vary according to the data. In this light, a bar chart is a mapping of the length of a bar to a magnitude of a variable. Since the graphic design of the mapping can adversely affect the readability of a chart, mapping is a core competency of Data visualization. Data visualization has its roots in the field of statistics and is therefore generally considered a branch of descriptive Statistics. However, because both design skills and statistical and computing skills are required to visualize effectively, it is argued by authors such as Gershon and Page that it is both an art and a science. Research into how people read and misread various types of visualizations is helping to determine what types and features of visualizations are most understandable and effective in conveying information.'

# %%
list1=Text.split()
print(list1)
# Out:
# ['From', 'an', 'academic', 'point', 'of', 'view,', 'this', 'representation', 'can', 'be', 'considered', 'as', 'a', 'mapping', 'between', 'the', 'original', 'data', 'and', 'graphic', 'elements.', 'The', 'mapping', 'determines', 'how', 'the', 'attributes', 'of', 'these', 'elements', 'vary', 'according', 'to', 'the', 'data.', 'In', 'this', 'light,', 'a', 'bar', 'chart', 'is', 'a', 'mapping', 'of', 'the', 'length', 'of', 'a', 'bar', 'to', 'a', 'magnitude', 'of', 'a', 'variable.', 'Since', 'the', 'graphic', 'design', 'of', 'the', 'mapping', 'can', 'adversely', 'affect', 'the', 'readability', 'of', 'a', 'chart,', 'mapping', 'is', 'a', 'core', 'competency', 'of', 'Data', 'visualization.', 'Data', 'visualization', 'has', 'its', 'roots', 'in', 'the', 'field', 'of', 'statistics', 'and', 'is', 'therefore', 'generally', 'considered', 'a', 'branch', 'of', 'descriptive', 'Statistics.', 'However,', 'because', 'both', 'design', 'skills', 'and', 'statistical', 'and', 'computing', 'skills', 'are', 're
# ...

# %%
count_dict={}
for i in list1:
    if i not in count_dict:
        count_dict[i]=1
    else:
        count_dict[i]+=1
print(count_dict)
# Out:
# {'From': 1, 'an': 2, 'academic': 1, 'point': 1, 'of': 12, 'view,': 1, 'this': 2, 'representation': 1, 'can': 2, 'be': 1, 'considered': 2, 'as': 2, 'a': 10, 'mapping': 5, 'between': 1, 'the': 8, 'original': 1, 'data': 1, 'and': 9, 'graphic': 2, 'elements.': 1, 'The': 1, 'determines': 1, 'how': 2, 'attributes': 1, 'these': 1, 'elements': 1, 'vary': 1, 'according': 1, 'to': 4, 'data.': 1, 'In': 1, 'light,': 1, 'bar': 2, 'chart': 1, 'is': 6, 'length': 1, 'magnitude': 1, 'variable.': 1, 'Since': 1, 'design': 2, 'adversely': 1, 'affect': 1, 'readability': 1, 'chart,': 1, 'core': 1, 'competency': 1, 'Data': 2, 'visualization.': 1, 'visualization': 1, 'has': 1, 'its': 1, 'roots': 1, 'in': 2, 'field': 1, 'statistics': 1, 'therefore': 1, 'generally': 1, 'branch': 1, 'descriptive': 1, 'Statistics.': 1, 'However,': 1, 'because': 1, 'both': 2, 'skills': 2, 'statistical': 1, 'computing': 1, 'are': 2, 'required': 1, 'visualize': 1, 'effectively,': 1, 'it': 2, 'argued': 1, 'by': 1, 'authors': 1, 'su
# ...

# %%
count_dict_new=dict(sorted(count_dict.items(), key=lambda item: item[1], reverse=True))
values=list(count_dict_new.values())
keys=list(count_dict_new.keys())
y= np.array(values)  
x=np.array(keys)   
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)
plt.plot(x, y)  
plt.xticks(x, rotation ='vertical')
plt.show()

# %%
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)
plt.bar(keys, values, color ='blue',
        width = 0.4)
plt.xticks(x, rotation ='vertical')
plt.show()

# %%
df.head()
# Out:
#    SD NO.                             SD_Name  YEAR   JAN   FEB    MAR    APR  \
# 0       1           ANDAMAN & NICOBAR ISLANDS  1951  82.7   7.2    0.0   45.4
# 1       2                   ARUNACHAL PRADESH  1951  31.8  65.3  309.9  441.0
# 2       3                   ASSAM & MEGHALAYA  1951   4.5   2.9   54.6  230.0
# 3       4  NAGALAND, MANIPUR, MIZORAM,TRIPURA  1951   3.9   0.2   62.4  360.1
# 4       5     SUB-HIMALAYAN W BENGAL & SIKKIM  1951   1.0   0.5   22.7   69.3
#
#      MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  JAN-FEB  \
# 0  259.0  619.9  665.3  101.3  360.9  489.0  209.6  434.8  3275.1     89.9
# 1  344.5  757.8  554.7  278.5  383.7  101.8   46.2   39.1  3354.3     97.1
# 2  270.6  688.4  665.9  444.4  241.5  302.2   46.3    5.4  2956.7      7.4
# 3  233.7  495.0  436.2  440.5  191.1  310.6   54.9   20.8  2609.4      4.1
# 4  239.8  546.5  778.3  503.7  326.1  158.0   37.3    0.0  2683.2      1.5
#
#    Mar-May  Jun-Sep  Oct-Dec
# ...

# %%
df['YEAR'].min()
# Out:
# 1951

# %%
df['SD_Name'].value_counts()
# Out:
# ANDAMAN & NICOBAR ISLANDS               64
# COSTAL ANDHRA PRADESH                   64
# SAURASHTRA KUTCH & DIU                  64
# KOKAN & GOA                             64
# MADHYA MAHARASHTRA                      64
# MARATWADA                               64
# VIDARBHA                                64
# CHATTISGARH                             64
# TELENGANA                               64
# EAST MADHYA PRADESH                     64
# RAYALSEEMA                              64
# TAMIL NADU & PONDICHERRY                64
# COASTAL KARNATAKA                       64
# NORTH INTERIOR KARNATAKA                64
# SOUTH INTERIOR KARNATAKA                64
# KERALA                                  64
# GUJARAT REGION, DADRA & NAGAR HAVELI    64
# WEST MADHYA PRADESH                     64
# EAST UTTAR PRADESH                      64
# EAST  RAJASTHAN                         64
# ASSAM & MEGHALAYA                       64
# NAGALAND, MANIPUR, MIZORAM,TRIPURA      64
# ...

# %%
df1=df.groupby('SD_Name')['ANNUAL'].agg('sum')

# %%
columns = ['Y'+str(i) for year in range(1951, 2014)]

df2=df.groupby(['SD_Name','YEAR'])['ANNUAL'].agg('sum')
print(df2.head(66))
# Out:
# SD_Name                    YEAR
# ANDAMAN & NICOBAR ISLANDS  1951    3275.1
#                            1952    3079.9
#                            1953    2722.0
#                            1954    3449.0
#                            1955    3349.6
#                                     ...
#                            2012    3516.0
#                            2013    2855.4
#                            2014    2622.4
# ARUNACHAL PRADESH          1951    3354.3
#                            1952    2396.1
# Name: ANNUAL, Length: 66, dtype: float64

# %%
columns = ['Y'+str(i) for year in range(1951, 2014)]
df2=df.groupby(['SD_Name'])['ANNUAL'].agg(Total_Annual='mean')
print(df2.head(66))
type(df2)
# Out:
#                                       Total_Annual
# SD_Name
# ANDAMAN & NICOBAR ISLANDS              2884.734375
# ARUNACHAL PRADESH                      2826.848276
# ASSAM & MEGHALAYA                      2684.375000
# BIHAR                                  1169.367188
# CHATTISGARH                            1294.606250
# COASTAL KARNATAKA                      3531.503125
# COSTAL ANDHRA PRADESH                  1012.089062
# EAST  RAJASTHAN                         654.276562
# EAST MADHYA PRADESH                    1158.765625
# EAST UTTAR PRADESH                      967.300000
# GANGETIC WEST BENGAL                   1506.414062
# GUJARAT REGION, DADRA & NAGAR HAVELI    931.621875
# HARYANA, DELHI & CHANDIGARH             545.826563
# HIMACHAL PRADESH                       1239.809375
# JAMMU & KASHMIR                        1138.668254
# JHARKHAND                              1258.209375
# KERALA                                 2838.317187
# ...

# %%
df3=pd.DataFrame(df2)

print(df3.head())
# Out:
#                            Total_Annual
# SD_Name
# ANDAMAN & NICOBAR ISLANDS   2884.734375
# ARUNACHAL PRADESH           2826.848276
# ASSAM & MEGHALAYA           2684.375000
# BIHAR                       1169.367188
# CHATTISGARH                 1294.606250

# %%
# state=list(df3['SD_Name'])
annual=list(df3['Total_Annual'])
# print(annual)
state=(df3.iloc[:,0:0]).index
print(state)
# Out:
# Index(['ANDAMAN & NICOBAR ISLANDS', 'ARUNACHAL PRADESH', 'ASSAM & MEGHALAYA',
#        'BIHAR ', 'CHATTISGARH', 'COASTAL KARNATAKA', 'COSTAL ANDHRA PRADESH',
#        'EAST  RAJASTHAN ', 'EAST MADHYA PRADESH', 'EAST UTTAR PRADESH',
#        'GANGETIC WEST BENGAL', 'GUJARAT REGION, DADRA & NAGAR HAVELI',
#        'HARYANA, DELHI & CHANDIGARH', 'HIMACHAL PRADESH', 'JAMMU & KASHMIR',
#        'JHARKHAND', 'KERALA', 'KOKAN & GOA', 'LAKSHADWEEP ',
#        'MADHYA MAHARASHTRA', 'MARATWADA ',
#        'NAGALAND, MANIPUR, MIZORAM,TRIPURA', 'NORTH INTERIOR KARNATAKA',
#        'ORISSA', 'PUNJAB ', 'RAYALSEEMA', 'SAURASHTRA KUTCH & DIU',
#        'SOUTH INTERIOR KARNATAKA', 'SUB-HIMALAYAN W BENGAL & SIKKIM',
#        'TAMIL NADU & PONDICHERRY', 'TELENGANA', 'UTTARANCHAL', 'VIDARBHA',
#        'WEST MADHYA PRADESH', 'WEST RAJASTHAN ', 'WEST UTTAR PRADESH'],
#       dtype='object', name='SD_Name')

# %%
print(len(annual))
state=list(state)
print(len(state))
# Out:
# 36
# 36

# %%
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)
plt.bar(state, annual, color ='blue',
        width = 0.4)
plt.xticks(state, rotation ='vertical')
plt.show()

# %%
# fig = plt.figure(figsize = (20, 5))
 
# creating the bar plot
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.plot(state, annual, color ='blue')
plt.xticks(state, rotation ='vertical')
plt.show()
